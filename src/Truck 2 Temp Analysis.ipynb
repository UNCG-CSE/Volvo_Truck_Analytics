# %%
import os
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
from scipy import stats

truckTwoPath = "../data/trucks/truck2.csv"

truckTwoDictPath = "../data/dictionary/truck2_data_dictionary.csv"

# %%
def get_truck_data():
    trucks2 = pd.read_csv(os.path.join('../data/trucks/truck2.csv'),
               sep=',',engine='python')
    
    return trucks2

# %%
trucks2 = get_truck_data()

# %%
def readCsv(truck):
    return pd.read_csv(truck, header = [0])
    
def cullUtcCols(truckData):
    noUTC = truckData.drop(["UTC hour", "UTC minute", "UTC second", "UTC month", "UTC day", "UTC year"], axis = 1)
    return noUTC

"""Takes a DataFrame and a conversion dictionary as parameters;
    uses the dictionary to rename all matching columns then returns the changed DataFrame."""
def renameColumns(dataFrame, dictionary):
    return dataFrame.rename(columns = dictionary)

"""Finds threshold of Non-NA type using percentage and deletes rows."""

#If the number of values that are NOT Na type pass this percentage, the row will be deleted
rowNaNThresholdPercent = 75
def removeUnnecessaryRows(dataFrame):
    length = len(dataFrame.columns)
    TValue = (rowNaNThresholdPercent / 100) * length
    print("Threshold value: " + str(int(TValue)))
    return dataFrame.dropna(thresh = int(TValue))

"""Finds columns with all Na types and deletes them."""
def removeUnnecessaryColumns(dataFrame):
    return dataFrame.dropna(axis=1, how='all')

# NOTE: The following function is unused in this notebook, but it can be used to convert CSV files into
# conversion dictionaries i.e. creating the column rename dictionaries, which was manually done in the
# previous block manually.

"""Creates a Python dictionary from a pre-defined CSV dictionary.
This will only look at the first two columns of the given CSV file."""
def createPythonDictionary(dictionaryCSV):
    # Initialize the resulting dictionary.
    dictResult = {}
    
    # Opens the passed in CSV which defines the rename dictionary and iterates through it to store each value into a Python dictionary.
    with open(dictionaryCSV, 'r') as f:
        for row in csv.reader(f):
            dictResult.update({row[0]:row[1]})
    return dictResult

# %%
trucks2 = removeUnnecessaryColumns(trucks2)

# %%
trucks2 = removeUnnecessaryRows(trucks2)
# Out:
# Threshold value: 32

# %%
trucks2.loc[:, 'AmbientAirTemperature_V']
# Out:
# 0          16.93750
# 1          16.93750
# 2          16.93750
# 3          16.93750
# 4          16.93750
# 5          16.93750
# 6          16.93750
# 7          16.93750
# 8          16.93750
# 9          16.93750
# 10         16.93750
# 11         16.93750
# 12         16.93750
# 13         16.93750
# 14         16.93750
# 15         16.93750
# 16         16.93750
# 17         16.93750
# 18         16.93750
# 19         16.93750
# 20         16.93750
# 21         16.93750
# 22         16.93750
# 23         16.93750
# 24         16.93750
# 25         16.93750
# 26         16.93750
# 27         16.93750
# 28         16.93750
# 29         16.93750
#              ...
# 1686293    13.40625
# 1686294    13.34375
# 1686295    13.34375
# 1686296    13.34375
# 1686297    13.34375
# 1686298    13.34375
# 1686299    13.34375
# 1686300    13.34375
# 1686301    13.34375
# 1686302    13.34375
# 1686303    13.34375
# 1686304    13.34375
# 1686305    13.34375
# 1686306    13.34375
# 1686307    13.34375
# 1686308    13.34375
# 1686309    13.34375
# 1686310    13.34375
# 1686311    13.34375
# 1686312    13.34375
# 1686313    13.34375
# 1686314    13.34375
# 1686315    13.34375
# 1686316    13.34375
# 1686317    13.34375
# 1686318    13.34375
# 1686319    13.34375
# 1686320    13.34375
# 1686321    13.34375
# 1686322    13.34375
# Name: AmbientAirTemperature_V, Length: 1686256, dtype: float64

# %%
trucks2['AmbientAirTemperature_V'].mean()
# Out:
# 11.41745914163482

# %%
trucks2['EngineAirIntakeTemp_BB1_X_E'].mean()
# Out:
# 10.926552278521473

# %%
trucks2.hist(column="AmbientAirTemperature_V", bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000136DD0E10>]],
#       dtype=object)

# %%
trucks2.hist(column="EngineAirIntakeTemp_BB1_X_E", bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000134F22D68>]],
#       dtype=object)

# %%
trucks2.hist(column='EngineCoolantTemp_stat', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000134685860>]],
#       dtype=object)

# %%
trucks2.hist(column='EngineOilTemperature', bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000012DF61080>]],
#       dtype=object)

# %%
trucks2.hist(column='EngExhaustGasTemp', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000134685710>]],
#       dtype=object)

# %%
trucks2.hist(column='EngIntakeManifold1Temp', bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000011CA3A9E8>]],
#       dtype=object)

# %%
trucks2.hist(column='TransmissionOilTemp', bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000112574B00>]],
#       dtype=object)

# %%
trucks2.hist(column='asu_UreaTankTemp', bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000112574588>]],
#       dtype=object)

# %%
trucks2.hist(column='tse_TurboSpeed', bins=500)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000010B523438>]],
#       dtype=object)

# %%
trucks2.loc[:, 'EngineAirIntakeTemp_BB1_X_E']
# Out:
# 0          16.0
# 1          16.0
# 2          16.0
# 3          16.0
# 4          16.0
# 5          16.0
# 6          16.0
# 7          16.0
# 8          16.0
# 9          16.0
# 10         16.0
# 11         16.0
# 12         16.0
# 13         16.0
# 14         16.0
# 15         16.0
# 16         16.0
# 17         16.0
# 18         16.0
# 19         16.0
# 20         16.0
# 21         16.0
# 22         16.0
# 23         16.0
# 24         16.0
# 25         16.0
# 26         16.0
# 27         16.0
# 28         16.0
# 29         16.0
#            ...
# 1686293    13.0
# 1686294    13.0
# 1686295    13.0
# 1686296    13.0
# 1686297    13.0
# 1686298    13.0
# 1686299    13.0
# 1686300    13.0
# 1686301    13.0
# 1686302    13.0
# 1686303    13.0
# 1686304    13.0
# 1686305    13.0
# 1686306    13.0
# 1686307    13.0
# 1686308    13.0
# 1686309    13.0
# 1686310    13.0
# 1686311    13.0
# 1686312    13.0
# 1686313    13.0
# 1686314    13.0
# 1686315    13.0
# 1686316    13.0
# 1686317    13.0
# 1686318    13.0
# 1686319    13.0
# 1686320    13.0
# 1686321    13.0
# 1686322    13.0
# Name: EngineAirIntakeTemp_BB1_X_E, Length: 1686256, dtype: float64

# %%
trucks2.loc[:, 'tse_TurboSpeed']
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
#                ...
# 1686293    73574.351562
# 1686294    73567.468750
# 1686295    73566.242188
# 1686296    73591.960938
# 1686297    73626.054688
# 1686298    73589.015625
# 1686299    73497.453125
# 1686300    73449.281250
# 1686301    73388.132812
# 1686302    73329.226562
# 1686303    73276.648438
# 1686304    73259.531250
# 1686305    73270.226562
# 1686306    73227.960938
# 1686307    73195.351562
# 1686308    73209.257812
# 1686309    73208.273438
# 1686310    73174.976562
# 1686311    73160.781250
# 1686312    73104.007812
# 1686313    73012.179688
# 1686314    72893.453125
# 1686315    72784.460938
# 1686316    72693.734375
# 1686317    72665.203125
# 1686318    72653.578125
# 1686319    72556.023438
# 1686320    72479.265625
# 1686321    72410.914062
# 1686322    72304.234375
# Name: tse_TurboSpeed, Length: 1686256, dtype: float64

# %%
trucks2['tse_TurboSpeed'].mean()
# Out:
# 51901.1815191138

# %%
truck = trucks2['tse_TurboSpeed']

# %%
truck1 = trucks2[['AmbientAirTemperature_V']].ffill().bfill()

# %%
truck3 = trucks2[['EngineAirIntakeTemp_BB1_X_E']].ffill().bfill()

# %%
truck1
# Out:
#          AmbientAirTemperature_V
# 0                       16.93750
# 1                       16.93750
# 2                       16.93750
# 3                       16.93750
# 4                       16.93750
# 5                       16.93750
# 6                       16.93750
# 7                       16.93750
# 8                       16.93750
# 9                       16.93750
# 10                      16.93750
# 11                      16.93750
# 12                      16.93750
# 13                      16.93750
# 14                      16.93750
# 15                      16.93750
# 16                      16.93750
# 17                      16.93750
# 18                      16.93750
# 19                      16.93750
# 20                      16.93750
# 21                      16.93750
# 22                      16.93750
# 23                      16.93750
# 24                      16.93750
# 25                      16.93750
# 26                      16.93750
# 27                      16.93750
# 28                      16.93750
# 29                      16.93750
# ...                          ...
# 1686293                 13.40625
# 1686294                 13.34375
# 1686295                 13.34375
# 1686296                 13.34375
# 1686297                 13.34375
# 1686298                 13.34375
# 1686299                 13.34375
# 1686300                 13.34375
# 1686301                 13.34375
# 1686302                 13.34375
# 1686303                 13.34375
# 1686304                 13.34375
# 1686305                 13.34375
# 1686306                 13.34375
# 1686307                 13.34375
# 1686308                 13.34375
# 1686309                 13.34375
# 1686310                 13.34375
# 1686311                 13.34375
# 1686312                 13.34375
# 1686313                 13.34375
# 1686314                 13.34375
# 1686315                 13.34375
# 1686316                 13.34375
# 1686317                 13.34375
# 1686318                 13.34375
# 1686319                 13.34375
# 1686320                 13.34375
# 1686321                 13.34375
# 1686322                 13.34375
#
# [1686256 rows x 1 columns]

# %%
truck
# Out:
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
# 14                  NaN
# 15                  NaN
# 16                  NaN
# 17                  NaN
# 18                  NaN
# 19                  NaN
# 20                  NaN
# 21                  NaN
# 22                  NaN
# 23                  NaN
# 24                  NaN
# 25                  NaN
# 26                  NaN
# 27                  NaN
# 28                  NaN
# 29                  NaN
#                ...
# 1686293    73574.351562
# 1686294    73567.468750
# 1686295    73566.242188
# 1686296    73591.960938
# 1686297    73626.054688
# 1686298    73589.015625
# 1686299    73497.453125
# 1686300    73449.281250
# 1686301    73388.132812
# 1686302    73329.226562
# 1686303    73276.648438
# 1686304    73259.531250
# 1686305    73270.226562
# 1686306    73227.960938
# 1686307    73195.351562
# 1686308    73209.257812
# 1686309    73208.273438
# 1686310    73174.976562
# 1686311    73160.781250
# 1686312    73104.007812
# 1686313    73012.179688
# 1686314    72893.453125
# 1686315    72784.460938
# 1686316    72693.734375
# 1686317    72665.203125
# 1686318    72653.578125
# 1686319    72556.023438
# 1686320    72479.265625
# 1686321    72410.914062
# 1686322    72304.234375
# Name: tse_TurboSpeed, Length: 1686256, dtype: float64

# %%
truck.describe()
# Out:
# count    1.624559e+06
# mean     5.190118e+04
# std      2.182253e+04
# min      0.000000e+00
# 25%      3.463129e+04
# 50%      5.498862e+04
# 75%      7.065277e+04
# max      9.174719e+04
# Name: tse_TurboSpeed, dtype: float64

# %%
truck = trucks2[['tse_TurboSpeed']].ffill().bfill()

# %%
truck
# Out:
#          tse_TurboSpeed
# 0          70969.250000
# 1          70969.250000
# 2          70969.250000
# 3          70969.250000
# 4          70969.250000
# 5          70969.250000
# 6          70969.250000
# 7          70969.250000
# 8          70969.250000
# 9          70969.250000
# 10         70969.250000
# 11         70969.250000
# 12         70969.250000
# 13         70969.250000
# 14         70969.250000
# 15         70969.250000
# 16         70969.250000
# 17         70969.250000
# 18         70969.250000
# 19         70969.250000
# 20         70969.250000
# 21         70969.250000
# 22         70969.250000
# 23         70969.250000
# 24         70969.250000
# 25         70969.250000
# 26         70969.250000
# 27         70969.250000
# 28         70969.250000
# 29         70969.250000
# ...                 ...
# 1686293    73574.351562
# 1686294    73567.468750
# 1686295    73566.242188
# 1686296    73591.960938
# 1686297    73626.054688
# 1686298    73589.015625
# 1686299    73497.453125
# 1686300    73449.281250
# 1686301    73388.132812
# 1686302    73329.226562
# 1686303    73276.648438
# 1686304    73259.531250
# 1686305    73270.226562
# 1686306    73227.960938
# 1686307    73195.351562
# 1686308    73209.257812
# 1686309    73208.273438
# 1686310    73174.976562
# 1686311    73160.781250
# 1686312    73104.007812
# 1686313    73012.179688
# 1686314    72893.453125
# 1686315    72784.460938
# 1686316    72693.734375
# 1686317    72665.203125
# 1686318    72653.578125
# 1686319    72556.023438
# 1686320    72479.265625
# 1686321    72410.914062
# 1686322    72304.234375
#
# [1686256 rows x 1 columns]

# %%
truck.hist(column='tse_TurboSpeed', bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000106294EB8>]],
#       dtype=object)

# %%
truck1.hist(column='AmbientAirTemperature_V', bins=100)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000001046849E8>]],
#       dtype=object)

# %%
np.var(truck1)
# Out:
# AmbientAirTemperature_V    22.460776
# dtype: float64

# %%
np.var(truck)
# Out:
# tse_TurboSpeed    4.690137e+08
# dtype: float64

# %%
np.std(truck)
# Out:
# tse_TurboSpeed    21656.723137
# dtype: float64

# %%
np.std(truck1)
# Out:
# AmbientAirTemperature_V    4.73928
# dtype: float64

# %%
ttest = stats.ttest_ind(truck['tse_TurboSpeed'], truck1['AmbientAirTemperature_V'])

# %%
ttest
# Out:
# Ttest_indResult(statistic=3087.282511934524, pvalue=0.0)

# %%
ttest = stats.ttest_ind(truck3['EngineAirIntakeTemp_BB1_X_E'], truck1['AmbientAirTemperature_V'])

# %%
ttest
# Out:
# Ttest_indResult(statistic=-94.97137593106267, pvalue=0.0)

# %%
ttest = stats.ttest_ind(truck3['EngineAirIntakeTemp_BB1_X_E'], truck1['AmbientAirTemperature_V'])

# %%
ttest
# Out:
# Ttest_indResult(statistic=-94.97137593106267, pvalue=0.0)

# %%
t1 = np.cov(truck.T, truck1.T)

# %%
t = np.corrcoef(truck.T, truck1.T)

# %%
t
# Out:
# array([[ 1.        , -0.09467137],
#        [-0.09467137,  1.        ]])

# %%
t1
# Out:
# array([[ 4.69013935e+08, -9.71681719e+03],
#        [-9.71681719e+03,  2.24607897e+01]])
